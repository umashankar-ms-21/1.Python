# %%
num1=10
num2=30
add=num1+num2

# %%
print(add)
# Out:
# 40

# %%
num1=10
num2=30
add=num1+num2
print("add")
# Out:
# add

# %%
num1=10
num2=30
add=num1+num2
print("add")
print(add)
# Out:
# add
# 40

# %%
Num1=40
Num2=50
Add=Num1+Num2
Sub=Num1-Num2

# %%
print(Add)
print(Sub)
# Out:
# 90
# -10

# %%
first name = "Umashankar"
# Out:
#   Cell In[7], line 1
#     first name = "Umashankar"
#           ^
# SyntaxError: invalid syntax

# %%
#either without space or with underscore

first_name = "Umashankar"
last_name = "M"

#or

firstName = "Umashankar"
lastName = "M"

#or

First_Name = "Umashankar"
Last_Name = "M"

# %%
FirstName = "Hello"
firstName = "Hi"

# %%
f2irst=30

# %%
# Output should be the below:#

# The addition of two numbers
# The number1 : 10
# The number2 : 20
# The Answer : 30

# %%
print("The addition of two numbers")
# Out:
# The addition of two numbers

# %%
num1=10
print("The Number1 :", num1)
# Out:
# The Number1 : 10

# %%
num2=20
print("The Number2 :", num2)
# Out:
# The Number2 : 20

# %%
add=num1+num2
print("The Answer :", add)
# or 
print("The Answer :", num1+num2)
# Out:
# The Answer : 30
# The Answer : 30

# %%
# input statement -- # Enter input by the end user 

num1=input("Enter the num1 :")
# Out:
# Enter the num1 : 30

# %%
num2=input("Enter the num2 :")
# Out:
# Enter the num2 : 50

# %%
# addition of both inputs
add=num1+num2

# %%
# why here the output haven't come out for addition of num1+num2 (30+50) = 80 
# instead the output as adjucent numbers of num1+num2 (30+50) ="3050",
# the end user's input considered as "string" by the programme instead of "integer"
print(add)
# Out:
# 3050

# %%
# hence need to add the "int" in prefix to "input" statement then the output will be "integer" calculation
num1=int(input("Enter the num1 :"))
# Out:
# Enter the num1 : 30

# %%
# if miss to add the close paranthesis then it leads to "SyntaxError: unexpected EOF while parsing" / EOF(end of file)
num2=int(input("Enter the num2 :"))
# Out:
# Enter the num2 : 50

# %%
# adding both num1+num2 here the answer will be integer
add=num1+num2

# %%
print(add)
# Out:
# 80

# %%
# the below received error due to the print statement searched in the memory and 
# then thrown as error for the reason of "no such name variables not defined or stored in the memory"
# "NameError" will get only for the two reason 1st is above and another for "spelling mistakes"
print(mul)  # "mul" used short word for multiplicatiion
# Out:
# 9

# %%
mul=9

# %%
print(add)
print(mul)
# Out:
# 80
# 9

# %%
# syntex prefix with "int" in the input statement, but the end user's input the text ("string") 
# then the error will thrown for ValueError

num=int(input("Enter your age :"))
# Out:
# Enter your age : 10

# %%
# If again do the Run option instead of Enter afer receive the input, so it will show like this astrick [ * ]:
# To rectify this GO TO "Kernel" option and click on "Restart Kernal and Clear outputs of all cells"
