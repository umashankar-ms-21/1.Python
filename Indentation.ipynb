# %%
# semi-colon after IF CONDITION enter the key and continue from the curser moved placement:
if(condition):
    print("Adult")

# %%
# semi-colon after FOR LOOP function also have the same condition to follow as per the curser moved placement:
for temp in range(1.11):
    #Curser always have this position after semi-colon follow the position, DO NOT write the the statement in straight row format

# %%
def():
