# %%
print()

# %%
print("welcome to hope ai")
# Out:
# welcome to hope ai

# %%
print("12345abcde")
# Out:
# 12345abcde

# %%
# python statements and variables are case sensitive hence it throws an NameError:
# print() statement incorrectly entered as caps "P" Print()

Print("welcome")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Print("welcome")
#
# NameError: name 'Print' is not defined

# %%
# Correct print() statement is below:
print("welcome")
# Out:
# welcome
