# %%
# meaning : "import" class name "from" the python saved library or file
from generalFunctions import multiFunction
# FROM "file name" IMPORT "class name"

# %%
multiFunction.AgeCategory()
# Out:
# Enter the age: 17
# Children
# 'Children'

# %%
multiFunction.BMI()
# Out:
# Enter the BMI Index: 30
# Very Overweight
# 'Very Overweight'

# %%
multiFunction.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multiFunction.oddEven()
# Out:
# Enter the number: 52452
# is Even Number
# 'is Even Number'

# %%
multiFunction.Eligible()
# Out:
# Your Gender : Male
# Your Age : 20
# NOT ELIGIBLE

# %%
multiFunction.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  95
# Subject4=  95
# Subject5=  93
# Total : 468
# Percentage : 93.599999999999994

# %%
multiFunction.triangle()
# Out:
# Height : 32
# Breadth : 34
# Area formula: (Height*Breadth)/2
# Area of Triangle : 544.0
# Height1 : 2
# Height2 : 4
# Breadth1 : 4
# Perimeter formula: Height1+Height2+Breadth1
# Perimeter of Triangle : 10

# %%
multiFunction.addition()
# Out:
# Enter a num1 : 25
# Enter a num2 : 75
# 100

# %%
multiFunction.subraction()
# Out:
# Enter a num1 : 25
# Enter a num2 : 75
# -50

# %%
multiFunction.multiplication()
# Out:
# Enter a num1 : 25
# Enter a num2 : 75
# 1875
